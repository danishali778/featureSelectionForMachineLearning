# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest

# %%
data = pd.read_csv('../../precleaned-datasets/dataset_2.csv')
data
# Out:
#           var_1      var_2         var_3     var_4     var_5     var_6  \
# 0      4.532710   3.280834  1.798248e+01  4.404259  2.349910  0.603264
# 1      5.821374  12.098722  1.330915e+01  4.125599  1.045386  1.832035
# 2      1.938776   7.952752  9.726712e-01  3.459267  1.935782  0.621463
# 3      6.020690   9.900544  1.786964e+01  4.366715  1.973693  2.026012
# 4      3.909506  10.576516  9.341910e-01  3.419572  1.871438  3.340811
# ...         ...        ...           ...       ...       ...       ...
# 49995  5.392593   1.336383  8.212083e+00  2.966147  2.387417  3.019191
# 49996  3.544616   5.376492 -5.253303e-07  3.469798  3.473573  4.555753
# 49997  4.266667   7.618359  1.728767e+01  3.241785  1.264538  2.392204
# 49998  5.130579   6.749948  1.060437e+01  3.578128  2.770539  2.089231
# 49999  4.537930   6.384039  1.694724e+01  4.297897  2.109488  1.058434
#
#           var_7     var_8      var_9     var_10  ...   var_100   var_101  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(columns=['target']),
                                                     data['target'],
                                                       test_size=0.2, random_state=42)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (40000, 108) (10000, 108) (40000,) (10000,)

# %%
anova = f_classif(X_train, y_train)
anova
# Out:
# (array([2.16998026e-03, 3.74212383e+01, 1.34626019e+01, 4.37054289e+00,
#         1.37468493e+01, 2.85358934e+01, 9.80186078e+00, 4.52374080e+00,
#         4.41577351e+00, 5.03167655e+00, 1.12422916e+00, 1.56142050e+01,
#         5.26521207e+01, 9.57146212e+00, 2.09168327e+01, 8.47678140e+02,
#         4.44706338e+01, 1.40520344e+01, 5.35160208e+00, 1.47214440e+01,
#         3.46694052e+02, 1.20657978e+00, 7.01963993e+00, 1.10542273e+00,
#         2.05408524e+00, 4.95690320e+01, 1.90756668e+00, 1.33722751e+01,
#         1.46943805e+00, 1.01913880e+02, 1.15458176e+01, 1.53595690e+00,
#         4.31490256e-01, 6.09718893e+02, 7.84725557e-01, 1.21673941e+01,
#         2.55726100e+01, 2.69551984e+01, 1.80752768e+00, 1.06157855e-02,
#         1.34701149e-01, 8.73041124e-01, 8.44645738e+00, 7.55658012e-02,
#         1.87595993e+01, 4.70108437e+00, 1.81924842e+00, 2.38887163e+02,
#         1.54219040e+00, 5.53459402e+00, 1.38708283e+01, 7.20326442e+00,
# ...

# %%
anova = pd.Series(anova[0], index=X_train.columns, name='F-value')
anova = anova.sort_values(ascending=False)
anova
# Out:
# var_55     2498.818988
# var_108     874.920618
# var_16      847.678140
# var_34      609.718893
# var_69      350.276546
#               ...
# var_44        0.075566
# var_78        0.024393
# var_101       0.013540
# var_40        0.010616
# var_1         0.002170
# Name: F-value, Length: 108, dtype: float64

# %%
sel = SelectKBest(f_classif, k=10)
sel.fit(X_train, y_train)
X_train.columns[sel.get_support()]
X_train.columns[sel.get_support()].tolist()
# Out:
# ['var_16',
#  'var_21',
#  'var_34',
#  'var_48',
#  'var_55',
#  'var_69',
#  'var_70',
#  'var_91',
#  'var_96',
#  'var_108']

# %%
X_train = sel.transform(X_train)
X_ttest = sel.transform(X_test)

X_train.shape
# Out:
# (40000, 10)
